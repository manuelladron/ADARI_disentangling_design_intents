# %%
import json
import spacy
import regex as re
import math
import numpy as np
import string
import unicodedata
from spacy.tokenizer import Tokenizer
from collections import Counter, defaultdict
from html.parser import HTMLParser
from IPython.display import clear_output

# %%
nlp = spacy.load('en_core_web_lg')

# To treat hyphenated word as tokens
infixes = tuple([r"'s\b", r"(?<!\d)\.(?!\d)"]) +  nlp.Defaults.prefixes
infix_re = spacy.util.compile_infix_regex(infixes)

def custom_tokenizer(nlp):
    return Tokenizer(nlp.vocab, infix_finditer=infix_re.finditer)

nlp.tokenizer = custom_tokenizer(nlp)

# %%
def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1

    block = int(round(bar_length * progress))
    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
# Path for file dset_dataloader.json
def open_json(path):
    f = open(path) 
    data = json.load(f) 
    f.close()
    return data 

def save_json(file_path, data):
    out_file = open(file_path, "w")
    json.dump(data, out_file)
    out_file.close()

def flatten(S):
    if S == []:
        return S
    if isinstance(S[0], list):
        return flatten(S[0]) + flatten(S[1:])
    return S[:1] + flatten(S[1:])

# %%
image_sents_p = '../../json_files/cleaned/ADARI_v2/furniture/ADARI_furniture_sents.json'
vocab_p = '../../json_files/cleaned/ADARI_v2/furniture/ADARI_furniture_vocab.json'

# %%
image_sents = open_json(image_sents_p)
vocab = open_json(vocab_p)

# %% [markdown]
# ### Document frequency

# %% [markdown]
# ###### Number of documents containing each word

# %%
def document_frequency(image_sents):
    """
    Takes in the image sents dictionary (image: (list of sentences,list of POS)) and returns for all words and for all adjs:
     - document frequency: number of documents containing each word (dictionary word: N) 
     - term frequency: term frequency of each word in each document divided by total words in each document
    """
    # document frequency
    df_all = defaultdict(int) 
    df_adjs = defaultdict(int)
    
    # term frequency
    tf_all = defaultdict(int)
    tf_adjs = defaultdict(int)
    
    ii = 0
    total_steps = len(image_sents)
    # For each entry (doc)
    for image_name, list_of_sents_pos in image_sents.items():
        update_progress(ii/total_steps)
        #if ii == 1: break
        text = '. '.join(list_of_sents_pos[0])
        doc = nlp(text)
        
        tokens = []
        token_adjs = []
        
        for token in doc:
            if token.is_stop == False and token.is_punct == False:
                tokens.append(str(token.lemma_))
                if token.pos_ == 'ADJ':
                    token_adjs.append(str(token.lemma_))
        
        # This chunk is for term frequency counts
        total_words_doc = len(tokens)
        total_adjs_doc = len(token_adjs)
        count_words = Counter(tokens)
        count_adjs = Counter(token_adjs)
        
        tf_all[image_name] = {word:count_words[word]/total_words_doc for word in count_words.keys()}
        tf_adjs[image_name] = {adj:count_adjs[adj]/total_adjs_doc for adj in count_adjs.keys()}
        
        # This chunk is for document frequency counts
        tokens_unique = list(set(tokens))
        token_adjs_unique = list(set(token_adjs))
        
        for token in tokens_unique:
            df_all[token] += 1 
        for token in token_adjs_unique:
            df_adjs[token] += 1
        
        ii += 1
        
    return df_all, df_adjs, tf_all, tf_adjs

# %%
df_all, df_adjs, tf_all, tf_adjs = document_frequency(image_sents)
# Out:
# Progress: [####################] 100.0%

# %%
def tf_idf(df_all, df_adjs, tf_all, tf_adjs):
    """
    df_all: dictionary word: number of documents containing that word (dictionary word: N)
    df_adjs: dictionary word: number of documents containing that adj (dictionary adj: N)
    tf_all: dictionary image_name: {word: word_counts/total words}
    tf_adjs: dictionary image_name: {adj: adj_counts/total adjs}
    
    Returns:
    tf-idf_all: dictionary with image_name: {word:tf-idf score}
    tf-idf_adj: dictionary with image_name: {adj: tf-idf score}
    """
    total_number_docs = len(tf_all.keys())
    tf_idf_all = defaultdict(float)
    tf_idf_adjs = defaultdict(float)
    
    # For all words
    ii = 0
    total_steps = len(tf_all.keys())
    for key, val in tf_all.items():
        update_progress(ii/total_steps)
        #if ii == 1: break
        # Each image name is going to have each label with the tf-idf value 
        tf_idf_all[key] = {w:val[w] * np.log((total_number_docs+1)/(df_all[w]+1)) +1 for w in val}
        ii += 1
    
    # For all adjs
    ii = 0
    for key, val in tf_adjs.items():
        update_progress(ii/total_steps)
        tf_idf_adjs[key] = {a:val[a] * np.log((total_number_docs+1)/(df_adjs[a]+1)) +1 for a in val}
        ii += 1
        
    return tf_idf_all, tf_idf_adjs

# %%
tf_idf_all, tf_idf_adjs = tf_idf(df_all, df_adjs, tf_all, tf_adjs)
# Out:
# Progress: [####################] 99.1%

# %%
a = tf_idf_adjs['62a2e48f4b0d47f7159c3d68a79da7551dda6615.jpg']

# %%
{k: v for k, v in sorted(a.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'well-priced': 1.4601795334745078,
#  'modern': 1.437268881379797,
#  'country-friendly': 1.279781542251678,
#  'three-piece': 1.2202387457839898,
#  'well-made': 1.2113859443097397,
#  'cute': 1.1962245369147158,
#  'mutual': 1.1781724147232506,
#  'high-backed': 1.175097892794079,
#  'spacious': 1.1734642239934738,
#  'occasional': 1.136851968095442,
#  'three-legged': 1.1317698303913002,
#  'online': 1.1258884898495598,
#  'certain': 1.1217065656943046,
#  'useful': 1.1201441264330274,
#  'contemporary': 1.1154466936543481,
#  'practical': 1.108760730747139,
#  'physical': 1.1054532275017581,
#  'main': 1.0947655277308481,
#  'international': 1.0864011442774633,
#  'old': 1.0729663560424263,
#  'circular': 1.0711460994741182,
#  'low': 1.068873806001108,
#  'simple': 1.0446401563072765,
#  'small': 1.040189851657591}

# %%
save_file_path = '../../json_files/cleaned/ADARI_v2/furniture/'
save_json(save_file_path + 'ADARI_furniture_tfidf_words.json', tf_idf_all)
save_json(save_file_path + 'ADARI_furniture_tfidf_adjs.json', tf_idf_adjs)

# %%
def select_top_K_adjs_dict(tf_idf_adjs, K):
    tf_idf_K = dict()
    ii = 0
    for image_name, val in tf_idf_adjs.items():
        s = {k: v for k, v in sorted(val.items(), key=lambda item: item[1], reverse=True)}
        tf_idf_K[image_name] = [adj for adj in list(s.keys())[:K]]
        ii +=1
    return tf_idf_K

# %%
topK_tf_idf = select_top_K_adjs_dict(tf_idf_adjs, 3)

# %%
topK_tf_idf
# Out:
# {'62a2e48f4b0d47f7159c3d68a79da7551dda6615.jpg': ['well-priced',
#   'modern',
#   'country-friendly'],
#  '3523c82bd34c61967adf37ec2e29d48a5e7ec8ac.jpg': ['well-priced',
#   'modern',
#   'country-friendly'],
#  '3bd82bce2d8355cde7d3e1ccf5a65fcb2646ed9b.jpg': ['work-from-home',
#   'glossy',
#   'green-stained'],
#  '85f5902ce0b71a59bdf0266972245961178177b9.jpg': ['work-from-home',
#   'glossy',
#   'green-stained'],
#  '44103e41775ea9df62261028e397c0507c862094.jpg': ['work-from-home',
#   'glossy',
#   'green-stained'],
#  '9e9de9bd9a69686d309dcd33b7fbd753789d9e4a.jpg': ['work-from-home',
#   'glossy',
#   'green-stained'],
#  'c4cd583f469f212c36c9d5515c622f053aaab6d0.jpg': ['work-from-home',
#   'glossy',
#   'green-stained'],
#  '54f06bffd316bf19db9de2a3ad3a3c1f2ee9147f.jpg': ['work-from-home',
#   'glossy',
#   'green-stained'],
#  'aaeadb2ee7f9ddeb1961219db61dd7b30c882fdc.jpg': ['modulus',
#   'fermented',
#   'predominant'],
#  '8b98cdc23ac5e9b3d0387eb8857ee88deaccf279.jpg': ['modulus',
#   'fermented',
#   'predominant'],
#  'b8f756b4f68c988bda651ef4aee7191d6632f945.jpg': ['modulus',
#   'fermented',
#   'predominant'],
#  'a16b45b6c2bf11b1d43a0b9f1a07b38237c76258.jpg': ['modulus',
#   'fermented',
#   'predominant'],
#  '1840db3e303ac08fe3a4bec3d6596753f7fb490b.jpg': ['modulus',
#   'fermented',
#   'predominant'],
#  '905a4da09122bf5ae2cabc68bc3d2a8d7f928758.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  '270a50e36af584c3808dbf7896addc68c18366d1.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  'd155a353b247dc4574c34dda72e43b024e1452b3.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  '0a119fd43ad0be101e04e4d750eef6feedd67e7f.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  'dfe69f686cfbc580b04b47e5eeef3bcd119b28a4.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  'd1dcb1a4c8a8694884a262c0e5fb1ccafe36883a.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  'ad720acc3bb819e76e82707ffb13a9a5aa06504a.jpg': ['able',
#   'lesser-used',
#   'baked'],
#  '0016754611f7e8c5ab024bea67be8af8041f1e59.jpg': ['mirrored',
#   'high-quality',
#   'asymmetric'],
#  '28d33a5108ec71ed9300de54a760f66fb12c31c9.jpg': ['mirrored',
#   'high-quality',
#   'asymmetric'],
#  'ab03eceeaafd05a43abf358c1a2ca12366c0a7ef.jpg': ['mirrored',
#   'high-quality',
#   'asymmetric'],
#  '7c623418975863169d64efbfc0f2c5249400bd04.jpg': ['outdoor',
#   'versatile',
#   'weatherproof'],
#  'c6ea0cd2570103c0afd60b99ffff9647f504291c.jpg': ['outdoor',
#   'versatile',
#   'weatherproof'],
#  'd1c4b99bcb6a628c1e6a76a5b3f9c30506737c74.jpg': ['chinese',
#   'international',
#   'fair'],
#  'c6c865e931899eacb60e0c2a3c6f6b29374a2335.jpg': ['chinese',
#   'international',
#   'fair'],
#  'ddccdbc456bbbe3f5cd509bf5db4803616b072e5.jpg': ['chinese',
#   'international',
#   'fair'],
#  'fce0d7ae0ae87b9b2eac02e55c4f16e3f13ef5b6.jpg': ['chinese',
#   'international',
#   'fair'],
#  '27755287ca053f4924845aa88413b38db2ff81ba.jpg': ['chinese',
#   'international',
#   'fair'],
#  '3f8a213abf8db3970035a1f7f93fe50331ac30d6.jpg': ['eco-package',
#   'corrugated-cardboard',
#   'corporate'],
#  'bd6ffbec53cfb94b1ef01708189b90c8e3957e60.jpg': ['eco-package',
#   'corrugated-cardboard',
#   'corporate'],
#  '6a5ce8931fd6f00d2481b0ba85c6a5b177efc874.jpg': ['eco-package',
#   'corrugated-cardboard',
#   'corporate'],
#  '2c01662d9575f5be5c50addb1a4cedae8ce6ade2.jpg': ['eco-package',
#   'corrugated-cardboard',
#   'corporate'],
#  'ae793fcb48aee6048c9903ae16a038021bd807b8.jpg': ['eco-package',
#   'corrugated-cardboard',
#   'corporate'],
#  'f48bafd0a2e717865b898b7071f125680549b4be.jpg': ['boundary',
#   'ornamental',
#   'conceptual'],
#  '1b5aead70dbab4afa9b4c887da3cd1817f4284cb.jpg': ['boundary',
#   'ornamental',
#   'conceptual'],
#  '0279e5e337a8beda5d329c68e713df1a0a7375b5.jpg': ['boundary',
#   'ornamental',
#   'conceptual'],
#  '64a51a8fd2a68124caa667088437a0fbb3c18440.jpg': ['boundary',
#   'ornamental',
#   'conceptual'],
#  'a6d6a6a1970ccd2f7333671b7dcf1fa8c209f235.jpg': ['environmental',
#   'non-recyclable',
#   'charitable'],
#  '097e9ebddd1aec587a74d12291ae9314f52a3a9b.jpg': ['environmental',
#   'non-recyclable',
#   'charitable'],
#  '5ceec95dbd7bf7747652daa4ee2f8028ec75a2ee.jpg': ['environmental',
#   'non-recyclable',
#   'charitable'],
#  '61c45dcc1122768be2c45f2c04cf4e4c25769fe4.jpg': ['healthy',
#   'comfortable',
#   'professional'],
#  '86e85d61ba29636d1599b1fd2942a7698224e127.jpg': ['healthy',
#   'comfortable',
#   'professional'],
#  '3e9d3102f1f6611f628618aec3a106b897286210.jpg': ['healthy',
#   'comfortable',
#   'professional'],
#  '0cfcc021965b155dca4573105d420e6c677370ef.jpg': ['healthy',
#   'comfortable',
#   'professional'],
#  'd3da911d9d031743fb2660c32eecafa9d6fa7bc7.jpg': ['healthy',
#   'comfortable',
#   'professional'],
#  'dfca7c0ee1d767a555927c0d3b21a6f57ad14e5f.jpg': ['black-dyed',
#   'dog-themed',
#   'hollywood-style'],
#  'ad8d362e3423d9f5244bee51fb8ceca5605f79e6.jpg': ['black-dyed',
#   'dog-themed',
#   'hollywood-style'],
#  '87f058487ea0d1bf20c4e7cbccb48f9d7520a16d.jpg': ['black-dyed',
#   'dog-themed',
#   'hollywood-style'],
#  '91573a317a21a697c1bec1331866ec930aa46ff4.jpg': ['black-dyed',
#   'dog-themed',
#   'hollywood-style'],
#  'dd939ee6f3c51763fc2145bebc64ec4b46922b0c.jpg': ['classical',
#   'musical',
#   'pandemic-friendly'],
#  '50cc91d8fdac702575658653828cfa8db36abed4.jpg': ['classical',
#   'musical',
#   'pandemic-friendly'],
#  '304d2a819a06fdfcf8112686ddc3e7e519b16b4b.jpg': ['classical',
#   'musical',
#   'pandemic-friendly'],
#  '19f03d7d2dc3a7ed22201afd7e25fa9cff350b11.jpg': ['classical',
#   'musical',
#   'pandemic-friendly'],
#  '63404667694ea716eb45e30194d391fec3f0586f.jpg': ['classical',
#   'musical',
#   'pandemic-friendly'],
#  '294f83e6a1a4e0da82819df4cf26ca72e0077835.jpg': ['hand-drawn',
#   'hyper-real',
#   'soft-open'],
#  'd70e91ac24a7ded9af8a0defff91a8b59d681763.jpg': ['hand-drawn',
#   'hyper-real',
#   'soft-open'],
#  'a89e3a509ebc1b8b7a178649f796a236cc010e7c.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '2817598f6f9cf9f03cf320e8897e4982f535aa7c.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '082fa5c60823c237db4e05678ff47976f68bd0b9.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  'f4a26ec849a6071815bfd996153305fb0a9466ab.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '7d383768925b2758e54cae6893c5a327568e7bf8.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '8ae47c1803a5ed4b223187f107774169a2e87125.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '985e03e6a7f1d1ccb3a40f1911a6123ff743c1d1.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '5563f2cf2f8ea0a7f8bde6bff24350703964b517.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  'f3d278df97699e026de90961d615e146e891022d.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  'a570d0219e77d39f461037e4d3479b040df6907a.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  '6227589219c7649acd37400086fee9c7bad842e8.jpg': ['ornamental',
#   'functional',
#   'placid'],
#  'fc9ccb252ecc29aacd9f9d1febd961572a2f0e4b.jpg': ['exquisite',
#   'post-industrialised',
#   'custom-dyed'],
#  '2a434454dd7b478941151124356dc3436d3e8187.jpg': ['exquisite',
#   'post-industrialised',
#   'custom-dyed'],
#  'c613fd37ff2d1a5065639530834e376f24d66207.jpg': ['exquisite',
#   'post-industrialised',
#   'custom-dyed'],
#  '46af666c907a2238a9b633f16aa9322b570be0aa.jpg': ['exquisite',
#   'post-industrialised',
#   'custom-dyed'],
#  '9ec79ae39c02d7eb276e1ac83e060a074a994dfc.jpg': ['exquisite',
#   'post-industrialised',
#   'custom-dyed'],
#  'e2a4c55c766ec0a2790844643a7ded04f136c4b4.jpg': ['exquisite',
#   'post-industrialised',
#   'custom-dyed'],
#  'cb0a0ecbb68ae237160a1c42ff4eb287d346b67f.jpg': ['wholesome',
#   'air-dried',
#   'environmentally-friendly'],
#  'df743a2e42024e93f365e1b7e02ddb36aa42fc8b.jpg': ['wholesome',
#   'air-dried',
#   'environmentally-friendly'],
#  'fe4caca16c1097aa5e584f8844047053984afecd.jpg': ['wholesome',
#   'air-dried',
#   'environmentally-friendly'],
#  'cb0e31c3421de82f407219d8684582602b1ce47e.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  'ecb532f877f49aa6b7cd9ef2832fb0a00774c6c8.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  '9026b594687f99f4f832b1b93ea4b4b44db34896.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  '489890fc55e88b8a45bc56d43c3b474def3bc88e.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  '80dce3b262a1c81488da5714f2ab36f9987bff6b.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  'ae4c15353f71b0ada0d785ec7a8d7f466576e524.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  '5a94fa4baa1ffda5bc70633f79963388b0212d81.jpg': ['antibacterial',
#   'smart',
#   'antiviral'],
#  '1b4d02ddfcd99829ae688be757eeaf1d79828ddf.jpg': ['flat-pack',
#   'chrome-based',
#   'polluting'],
#  '719ff948bb1c0ab31737084b82b502d737937006.jpg': ['flat-pack',
#   'chrome-based',
#   'polluting'],
#  'fed5787e98afeb8848c2b34dcce688db6235c4ce.jpg': ['flat-pack',
#   'chrome-based',
#   'polluting'],
#  '2c57817c8464ec9415132e9fa070f80074b403d1.jpg': ['flat-pack',
#   'chrome-based',
#   'polluting'],
#  'b280e93e6390c67a554f6a2a790ed820aa9cf861.jpg': ['flat-pack',
#   'chrome-based',
#   'polluting'],
#  'c91470b21fae96f2b67a6526a1e7cffaec5823c8.jpg': ['flat-pack',
#   'chrome-based',
#   'polluting'],
#  'c0b939a4819441f4bd2b3f2973d494f59ba87e44.jpg': ['wry', 'venetian', 'floaty'],
#  'd53c45977c094b9a01e68912678c34be92bae57f.jpg': ['wry', 'venetian', 'floaty'],
#  '351ef544e4bf33fcbd1f106805d0a5a3582fb337.jpg': ['wry', 'venetian', 'floaty'],
#  '4494538ef47135aad9404463726f1ff3e94a41c4.jpg': ['wry', 'venetian', 'floaty'],
#  '5f2ce6090ebb4f105f258a39a29776abc6b1bfa7.jpg': ['wry', 'venetian', 'floaty'],
#  '9c3467e4674050ef88a5d2904784538d3b622354.jpg': ['worried', 'aren', 'kinked'],
#  'ade461e3bb0144f1843f6beb21b3a0a614e79657.jpg': ['worried', 'aren', 'kinked'],
#  '0c3d2bbfb85d2bf89e400e2a40d5040deee5ed6f.jpg': ['worried', 'aren', 'kinked'],
#  '93b028c0c23c2136c521137d867d6bf4e2afbf26.jpg': ['worried', 'aren', 'kinked'],
#  'bae995a5a4352af3deafd967a7a91eb4a642fc27.jpg': ['archival',
#   'cubic',
#   'zoomorphic'],
#  'e994b1e73ac8f17b0eadc15db7c4022fe841a83c.jpg': ['archival',
#   'cubic',
#   'zoomorphic'],
#  '8879195b37d9bef97afa8991868342cb21bd77c3.jpg': ['archival',
#   'cubic',
#   'zoomorphic'],
#  '4b2ddc6f0b29c35bb68d5c02ae7bca62e9a462d3.jpg': ['archival',
#   'cubic',
#   'zoomorphic'],
#  'c15a2700bf7a407e013fdd9b63bd486f6502cf59.jpg': ['archival',
#   'cubic',
#   'zoomorphic'],
#  '51caa56548c0e8b86b0213fc0ce54e8a8fe3bd0f.jpg': ['archival',
#   'cubic',
#   'zoomorphic'],
#  'a3db6df55bc25c1d0bb790131999a57a03161f11.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  '4ddc059c16504c769598c3f0a3ccab3183e53de1.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  '420d2abc4d32b5ed26f64a77fc0f3fac197b98b4.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  '5e830d3de5c6fdf40d67d58b57fde0861f7821d7.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  '15660e33150e9ccf967487dd7985e5baf254322b.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  'e9d9b1f1af0faed6272a033427ca8e026050d1a6.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  'c30dd0b37776397f429c6bd1f2575fd015ecc5e5.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  'f828d8396638f6d2f0f05f6f51406c4ea4b9307f.jpg': ['rural',
#   'rapid',
#   'temporary'],
#  '10acde2df6e868e4b7107558a998ff5cbc7c8f5e.jpg': ['charismatic',
#   'clay-like',
#   'affective'],
#  'b35601b22c1abf20e68d77dc7277505f0de8f2dd.jpg': ['charismatic',
#   'clay-like',
#   'affective'],
#  '8e8753d0e80465fd3a715fcbc0a78c4328508ac9.jpg': ['charismatic',
#   'clay-like',
#   'affective'],
#  'c1b8fc440501e6f89c8331ea719152d921e2837c.jpg': ['charismatic',
#   'clay-like',
#   'affective'],
#  'b4763048b574a4baa86ea88fa20c65ead0df4161.jpg': ['charismatic',
#   'clay-like',
#   'affective'],
#  '1d0ae4341a53937088c9396815d44dd2b51293cc.jpg': ['charismatic',
#   'clay-like',
#   'affective'],
#  '67f980200a7d77cdcae1ae7ce5ff08d04f457612.jpg': ['doughy',
#   'oil-coated',
#   'frontal'],
#  '382f63de378d58a06f7be6bfd093b1e1898ef818.jpg': ['doughy',
#   'oil-coated',
#   'frontal'],
#  '54b011f781b9ad71431442d78603f64d14092834.jpg': ['doughy',
#   'oil-coated',
#   'frontal'],
#  '25e8fc60306f1222369573b0bef9bd57d00a228b.jpg': ['doughy',
#   'oil-coated',
#   'frontal'],
#  '11ec889fb1c33f610f2b88ecd5589c4cdfb5d417.jpg': ['danish',
#   'sustainable',
#   'fibre-based'],
#  '74cb993b8e6883deb39f138abc465b5a761aebb6.jpg': ['danish',
#   'sustainable',
#   'fibre-based'],
#  '71689e3e23c0515490a7dcef3065b8be7ed39dca.jpg': ['danish',
#   'sustainable',
#   'fibre-based'],
#  '465493937412a8788273a8d9518611b095822ad8.jpg': ['danish',
#   'sustainable',
#   'fibre-based'],
#  'b5d242507ccef46a2b6f579b77e8aee7cfe81c28.jpg': ['danish',
#   'sustainable',
#   'fibre-based'],
#  '8fcc73a0d29c1c66e43c23eb786907fc9bb8ab71.jpg': ['danish',
#   'sustainable',
#   'fibre-based'],
#  'f1270d0734a31031c8d6cf92d425811cb89d22b0.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  'b01657d19e9144e4874d597a67298c68c0315b67.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  'e7433154c626b81a9b57c6cae2f5dab24a99e39a.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  '66a4bf208eccdb28c3a11b1a6c1d5ea954b5fc3a.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  '588f788d29790c7999393d3581b6c4e6ab97bcb1.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  '31e10e0843f1019aae0fc4d9386dd7a028e0cc87.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  'fc6347394efb66caa294c77c710ae6f7a2fa6783.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  'f2d249c1f973e568578f95a12ff246bb20e880c2.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  'f86bbd7c3eb44983ec770c5ec45f31817cce9ed1.jpg': ['ukurant',
#   'blind',
#   'squishy'],
#  '9ff7ed28ffbf661c48d25443c9058a1bd7b4a1c9.jpg': ['asian', 'nordic', 'happy'],
#  '3fd396e33d09eb2674e5239bd4350d47fe5e6551.jpg': ['asian', 'nordic', 'happy'],
#  'b2723e14c52ee5260fe4cfa43682912074e71cfd.jpg': ['asian', 'nordic', 'happy'],
#  'f8dcb0f2db6b16a60550fbe985d8dca7796ee072.jpg': ['blue', 'elaborate', 'deep'],
#  '66487c6a20497272bbfa39908679feae22b3dcee.jpg': ['blue', 'elaborate', 'deep'],
#  '38e04129e9aa7a84e88642320ecc79ae6d040a73.jpg': ['blue', 'elaborate', 'deep'],
#  '03df31452069b9478f1316bbc21d79d452e70aa4.jpg': ['blue', 'elaborate', 'deep'],
#  '7346b04d4c29aa2ab935895f7ec81809e0c5171b.jpg': ['blue', 'elaborate', 'deep'],
#  '18aa4cba6173e6adba0d04ac5cc68bee9a02fc73.jpg': ['blue', 'elaborate', 'deep'],
#  '800a12082a9c5bf2dda0f9459deaf040ecda1066.jpg': ['virginal',
#   "'stable",
#   'sophisticated'],
#  'd7b10cd900ac8c0d5dfcce605d9e7e8da92222e9.jpg': ['virginal',
#   "'stable",
#   'sophisticated'],
#  'b4573bc08185d97c15434376dda010228dfe6461.jpg': ['virginal',
#   "'stable",
#   'sophisticated'],
#  '0d2a5b0b1ec315fe2c35f218715c88de4ffaaad0.jpg': ['virginal',
#   "'stable",
#   'sophisticated'],
#  'ea36c032e304eda6b7ea4185ea6b0fbac846780d.jpg': ['virginal',
#   "'stable",
#   'sophisticated'],
#  '11bebd82fe676c96066e28feb69a912f5d1e4bff.jpg': ['virginal',
#   "'stable",
#   'sophisticated'],
#  '5ea2e058a32a1d54c6d55bb0213e86051c2234a7.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  '53ee9fde13fd3bf8698fa41a43fbd043f40bfed7.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  'ebbf78c1c302dcfc06875b3240c17f7bdf14ae34.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  '26af3f70432d0f7cb568a80bd847415620af7642.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  '6561c1a9dd515e188a648a93804b6cbc56452864.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  '5801ae4f62c5c83c894ef3ee7856db51cde423cc.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  'a4ae99453d2c6f0da83759cfb86971ddc96789f4.jpg': ['fungi-like',
#   'brick-red',
#   'fungi-inspired'],
#  'd5357723398ba3d21015cd5bf2b4b43f342a3bca.jpg': ['concrete',
#   'glass-fibre',
#   'pigmenting'],
#  '58f4b9a4d5137fc419b20bcdc1f880f19c4f3985.jpg': ['concrete',
#   'glass-fibre',
#   'pigmenting'],
#  '46effb7c87055a104a5bce6e5a5ccae36886098c.jpg': ['concrete',
#   'glass-fibre',
#   'pigmenting'],
#  '478758fc6f02fd8f2d0cd04d35dfaa43cd30e4a4.jpg': ['primitive',
#   'pixellated',
#   'artistic'],
#  '8d83295e177d1d512a293713b7fa895bd9c86fbe.jpg': ['primitive',
#   'pixellated',
#   'artistic'],
#  '4125b109ab37d243ea1380f8fc9aa0a0306a9dfa.jpg': ['primitive',
#   'pixellated',
#   'artistic'],
#  '2d9af05125ac6fb10ad2f13abf4d98ea84d50e36.jpg': ['primitive',
#   'pixellated',
#   'artistic'],
#  'bb146b2fc6ffa0f9784ea67ee6ae0e848933da8d.jpg': ['primitive',
#   'pixellated',
#   'artistic'],
#  '6bd2dc34bd5cb2f1bacae552b39767e65571e967.jpg': ['japanese',
#   'cotton-filled',
#   'table-like'],
#  '86008b618eb037eb4bec91d166ecd5a49d7a9b0d.jpg': ['japanese',
#   'cotton-filled',
#   'table-like'],
#  '43273270a73be999b01c8c3954a0f69130066924.jpg': ['japanese',
#   'cotton-filled',
#   'table-like'],
#  'c2059a2e7cd21c86354561775ac036f0a8f1357b.jpg': ['japanese',
#   'cotton-filled',
#   'table-like'],
#  'f2c785219981a884cdd000feacbf79ce14b32ee3.jpg': ['japanese',
#   'cotton-filled',
#   'table-like'],
#  '94e99e20a180801005a1ef38488291136b6f17d3.jpg': ['resilient',
#   'streamlined',
#   'mechanical'],
#  '3cf319f23e250cbaa6d30bf1a9a237eaa0225624.jpg': ['resilient',
#   'streamlined',
#   'mechanical'],
#  'efc3f9cdc7c3d33895f357099828b141d4acaaf6.jpg': ['resilient',
#   'streamlined',
#   'mechanical'],
#  'b872dc875d67e3475328b091b1f0cc1b74851b76.jpg': ['resilient',
#   'streamlined',
#   'mechanical'],
#  '5b87b768e8a2bec5548373e0b94fc2f51781c5ec.jpg': ['resilient',
#   'streamlined',
#   'mechanical'],
#  'cbca81e6738fccc234e50891dcde0d6e0da795c0.jpg': ['resilient',
#   'streamlined',
#   'mechanical'],
#  '8496998e6f7dcb65965f4c283e22363774632e42.jpg': ['angular',
#   'foam-like',
#   'matte-black'],
#  '2b081e8b915e8b5c285922d5a2e4d1b61711018f.jpg': ['angular',
#   'foam-like',
#   'matte-black'],
#  'b50b24b7afdf535873fd9e009b7ca67b1785eeb5.jpg': ['angular',
#   'foam-like',
#   'matte-black'],
#  '10507d6b29a728ed76793507f41d985d66f8bbd7.jpg': ['angular',
#   'foam-like',
#   'matte-black'],
#  '559099c2fe1d5000b029f09dc7aad2952c6e8e1a.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '00c650b27222c7f36ffe41460e5b4d4266c4d0ff.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  'fd9cc62ad8c233cd38a4421fede32627c3f3ab70.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '8c19c865af2ea317316701122cc95529daf538e9.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '73ac881cecafb43760bad45e9021dd7f09f675be.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '2361934cb118697cec26e1b12995ce0386bce3ba.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '940538c29b84a90733c47bdf3121b1ce01b8818f.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '7845b71663025769a88968e8be60f1d7d843f1d5.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  'f280bbf693c33a17744229774b41fc16959ee49b.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  'fd22e3eb2938082bceb2d90432d1da5efd329756.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '2f9f78122b1125bb086fad64760aea25ab0daba3.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '3b73fc7995009d654d4e4ac2ceaad9ccbb3f778a.jpg': ['corrugated-cardboard',
#   'polar',
#   'faceted'],
#  '0878ffd020e8e0f08081d05a8291e8919656845f.jpg': ['multiple',
#   'timber-lined',
#   'double'],
#  'f5007896f51551a4c7091451cf132bd1a2581ca6.jpg': ['multiple',
#   'timber-lined',
#   'double'],
#  '1a0f7caf773d012745464a6375e1c2849856289f.jpg': ['multiple',
#   'timber-lined',
#   'double'],
#  '57587158fda8d1f02a6de1ba0cb48861bf63db48.jpg': ['multiple',
#   'timber-lined',
#   'double'],
#  'fda65748d3b13345004f207a758629b1a0e2422c.jpg': ['multiple',
#   'timber-lined',
#   'double'],
#  '54b859e2235fdd9793a8d18c3ef7f27c084cb463.jpg': ['multiple',
#   'timber-lined',
#   'double'],
#  '4c0122d03946f923390ee517e858c63cae25677b.jpg': ['timeless',
#   'flatpack',
#   'seamless'],
#  'b06dc3f929df0f1f31c247d2eb007091bbfffd32.jpg': ['timeless',
#   'flatpack',
#   'seamless'],
#  '409759ecdd0ceb5996d464fb9d76a7765515f789.jpg': ['timeless',
#   'flatpack',
#   'seamless'],
#  '371ee3397c262ec88605f6e603c3d66be346d7ff.jpg': ['timeless',
#   'flatpack',
#   'seamless'],
#  'd706f1e5f054f8b599ec7dda9dbfe513b110c19d.jpg': ['timeless',
#   'flatpack',
#   'seamless'],
#  '90cebd70e0ecf2439ee6232396835c1a3d613b29.jpg': ['secret',
#   'repeated',
#   'complete'],
#  'f42c6353c31203c90f0aca1c26cb24c35377f903.jpg': ['secret',
#   'repeated',
#   'complete'],
#  '25913e3a94bfef7f3fb02455cfdf4d504bb29fec.jpg': ['poetic',
#   'utrecht-based',
#   'soft'],
#  'a981d0c2e1c1569cd56fff13701828ccbe027e12.jpg': ['poetic',
#   'utrecht-based',
#   'soft'],
#  'ac7a2fa11cf7597776b36ebd916c6c3b58c5419e.jpg': ['poetic',
#   'utrecht-based',
#   'soft'],
#  '1430dd558b64c49d1262fe9ea210999c23b04e29.jpg': ['poetic',
#   'utrecht-based',
#   'soft'],
#  '2f643335cc99871e273ff46f81dcfcfd1e60bbf0.jpg': ['poetic',
#   'utrecht-based',
#   'soft'],
#  'd5352b5eb3d0a795bc63e369cf6982d58762bc31.jpg': ['poetic',
#   'utrecht-based',
#   'soft'],
#  'e19f227f270f3411378df3d42157e258a60b781b.jpg': ['sancal',
#   'unclear',
#   'indoor-outdoor'],
#  '5b9e7c107bfc107c41a6f2da0d6a958ff046ca51.jpg': ['sancal',
#   'unclear',
#   'indoor-outdoor'],
#  '50d76369e5a9d71a1f0a2ad2665695e8fdd4e7ec.jpg': ['sancal',
#   'unclear',
#   'indoor-outdoor'],
#  '79919b1e7ee9be2fa57d759e672401f8f8d15e8c.jpg': ['roman',
#   'blocky',
#   'soft-white'],
#  '268f09e4f5461ce22c0684524bcc081e86e76c8d.jpg': ['roman',
#   'blocky',
#   'soft-white'],
#  '0f4774baa53b287130413328cd3788a54752289a.jpg': ['roman',
#   'blocky',
#   'soft-white'],
#  '6c381fc2a977213d6524906c04c9a5f6f800fabd.jpg': ['roman',
#   'blocky',
#   'soft-white'],
#  '534f773474a22917a990f4da5eec2672a4526dec.jpg': ['tidal',
#   'chunky',
#   'hand-poured'],
#  '6ffc1ad637abe37102d57554a4a88777ea58b61c.jpg': ['tidal',
#   'chunky',
#   'hand-poured'],
#  'e6db790160881f7ecbdeb21f054c5f680469e1fa.jpg': ['tidal',
#   'chunky',
#   'hand-poured'],
#  '35b6655cc6367d1b720d27df9abababd3f445b5f.jpg': ['tidal',
#   'chunky',
#   'hand-poured'],
#  '336095cd815d0662ecb70c978fc5a335c2fffd73.jpg': ['outdoor',
#   'off-road',
#   'drought-tolerant'],
#  'c720a857971cdcec3fc6ef01dbd130de1baab2e2.jpg': ['outdoor',
#   'off-road',
#   'drought-tolerant'],
#  '43788f459b4b1fe4109e61d37c948c90ca2a333b.jpg': ['showcase',
#   'sloped',
#   'hand-drawn'],
#  '6f96d12330a85662a19d90180e322467fc55106e.jpg': ['showcase',
#   'sloped',
#   'hand-drawn'],
#  '72aa7cec2fa3475a7243e005eb233c712d18921c.jpg': ['showcase',
#   'sloped',
#   'hand-drawn'],
#  '9b270fcb4f006089ab974bb740242203ac2d6054.jpg': ['tufted',
#   'ultimate',
#   'ergonomic'],
#  '8518c637d6ab503bed73d240980b2d0abed5073c.jpg': ['tufted',
#   'ultimate',
#   'ergonomic'],
#  '123c3ae694cc31bd6668116f2c08b4e8c0005e10.jpg': ['tufted',
#   'ultimate',
#   'ergonomic'],
#  '408197e82fbde66422b1b7ce55a0c4cffda07fff.jpg': ['tufted',
#   'ultimate',
#   'ergonomic'],
#  'b9f3346da1cc1fed62012d94124b0d3e101a0109.jpg': ['tufted',
#   'ultimate',
#   'ergonomic'],
#  'f207eda487279fdff93487ad37e44ecd269b691e.jpg': ['tufted',
#   'ultimate',
#   'ergonomic'],
#  '221e0cf337d82f5df8ae23151ce51d475fa71755.jpg': ['eurocentric',
#   'black',
#   'african'],
#  'fcaa5b7249c6e3a4859cd9b4fbe7a67995f606e1.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '809579737341465094c93c4799268d9048cb422d.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  'cbed93b0b2f4f12ae302f632038021723c6078f7.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '79bc18117d9ca6fcba300c16f6d53f2983e3609b.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  'e8cceb0c8a12ac712093abdf9d108095063a7634.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '1feac5ba99e12c91d759a47364986ae88d5dc582.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '53acfcdcc79be27d1a45fb527ce57bcd6cbd5b53.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '8592e1287b6670796fbac412c78696f2492bb515.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '546bb61ed7d4fadaaf79935f20d19a978f68fd93.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '52c2f4ed25e4e76294d5c860c344bd5a64973a6f.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  'c32c6c3818a0dc3a26cab35fa0638903fd9da58a.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  'b9ab6c1e371d9c98c8227a5d93f62d02a97bd718.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '4f44d895ded117fcbb4ade4aaa2a4c0139097d02.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  'c5e997e778379c5cc676cfb39791d4d5e718c822.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  '4c0e4150748b7325f23215d13c4a3f33b1de89ac.jpg': ['corrugated-cardboard',
#   'remote',
#   'soban'],
#  'c893aed4da3b69017f9f4bc00abf99eebcbb22d3.jpg': ['emotionless',
#   'cubist',
#   'nuclear'],
#  '8aaefa1fde9a744b3b630455003e6b1eb09c7b6f.jpg': ['emotionless',
#   'cubist',
#   'nuclear'],
#  '57e8ccc334c2ea34a1fbe0aaa042839e31dd818e.jpg': ['emotionless',
#   'cubist',
#   'nuclear'],
#  '85dba6dbfbc79ecc8e3f647c4d446fc361eabaef.jpg': ['voluptuous',
#   'contoured',
#   'tubular'],
#  '1be089a013d7461ab0b054a3ccbf758a6c19af92.jpg': ['voluptuous',
#   'contoured',
#   'tubular'],
#  '2471959db83d0f60d85f7c0cb8567f18ded78b64.jpg': ['voluptuous',
#   'contoured',
#   'tubular'],
#  'f589de67ec813ab10b8fe570fb431e1848f84ba4.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  '4604a00a8558bb5e743500d6f4bd8797de7fe227.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  '94a75c5e750005c50b5078a89b2d33a74f9b0017.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  'ac3212389fe5b268e539d05d8a8afcfc58ad4863.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  '01187ca696e946591de25402ac0b842299a9b4da.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  'af78a7682b6235596afc870ac8a5f05cb62760d1.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  '3f12221a381d6864d5f35505edf67c8165883bef.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  '90d5f360d38aa738778a84808514d816af0c8a51.jpg': ['african',
#   'ghanaian',
#   'ethiopian-american'],
#  'efa1bb9de06d958811c6eac4d2498eb6d1cddb7c.jpg': ['social', 'modular', 'kiik'],
#  '1241c5f66f6be1c1583a8d967eb0b3c469da8ef1.jpg': ['social', 'modular', 'kiik'],
#  'efaa5863d0fc711417efb1570d95524f57f5e743.jpg': ['social', 'modular', 'kiik'],
#  '9e8095195b6d365e7cc85b8d1906702121031a85.jpg': ['social', 'modular', 'kiik'],
#  '0085fa80497e567893d5868774572984925a87a9.jpg': ['uncompromised',
#   'resident',
#   'sole'],
#  'f9b384865ccfae375ed826bc1c00dd075d4be4f5.jpg': ['uncompromised',
#   'resident',
#   'sole'],
#  'a9e13e8e67dfc08027296510c563c447628eb296.jpg': ['uncompromised',
#   'resident',
#   'sole'],
#  'fa3d2778c085d42258b78ab6ad809998b0a32af1.jpg': ['captioned',
#   'post-lockdown',
#   'customisable'],
#  'f9586ea99b4ea4b44a527c12e9c0f1746424260a.jpg': ['captioned',
#   'post-lockdown',
#   'customisable'],
#  '34d9f04690f95a8269c5665c111b2525310acc8f.jpg': ['captioned',
#   'post-lockdown',
#   'customisable'],
#  '44c1eb9ac4753d567aa8ef543dc605f0e7b0072c.jpg': ['captioned',
#   'post-lockdown',
#   'customisable'],
#  '9712ce428e1689a67ac730cdb56cc7555c4c970f.jpg': ['nature-based',
#   'house-like',
#   'stepped-level'],
#  '162f3ff582466eca07a918031a3bc90df2c9a682.jpg': ['nature-based',
#   'house-like',
#   'stepped-level'],
#  'e2ac8737101f0f65139197dedfbf041bdc59558b.jpg': ['nature-based',
#   'house-like',
#   'stepped-level'],
#  '734f284c316d45f9fd4f85d6fab5599a09e9e899.jpg': ['nature-based',
#   'house-like',
#   'stepped-level'],
#  '668e38ead6c7b0b3e59a60893eac41c620052453.jpg': ['nature-based',
#   'house-like',
#   'stepped-level'],
#  '3f60333b897a309ddc63b4159609126d72b9bc17.jpg': ['nature-based',
#   'house-like',
#   'stepped-level'],
#  '0f75a68ec81c81e8f24b06a93d5d76c74dccf3f8.jpg': ['telar',
#   'outdoor',
#   'playful'],
#  '741ffe9142e6b74732036da3e8c8d6b1489d3e47.jpg': ['telar',
#   'outdoor',
#   'playful'],
#  'a0d8ee5729f0c593682f54e437dd7ad195dd252a.jpg': ['millimetre-square',
#   'bare',
#   'humble'],
#  'e707ba4b3651f05d933e014789fde6256a9c27bc.jpg': ['millimetre-square',
#   'bare',
#   'humble'],
#  '4c3bab789968cf995644981643043a65c0d9f856.jpg': ['millimetre-square',
#   'bare',
#   'humble'],
#  '1229f28684351c2918247dddeb095c58a10d5753.jpg': ['millimetre-square',
#   'bare',
#   'humble'],
#  '4ab7e07333bdbd965da3b60871d214d16ab5ded0.jpg': ['millimetre-square',
#   'bare',
#   'humble'],
#  '572df0f6a379df77aa5a73dd11e4ab7d50a03dd5.jpg': ['millimetre-square',
#   'bare',
#   'humble'],
#  'd28433567558f9a67fc7922f251c8c0745f20510.jpg': ['transparent',
#   'positive/negative',
#   'greenish'],
#  'daaf0a0a4c84c362edc51392724508c4a41e279e.jpg': ['transparent',
#   'positive/negative',
#   'greenish'],
#  '72b2cdf0a34e802b391ac1f1fc42e7177c7e8366.jpg': ['transparent',
#   'positive/negative',
#   'greenish'],
#  '7ebd53ed5bcafd883ca39e2d3ba190b5ee20eb34.jpg': ['transparent',
#   'positive/negative',
#   'greenish'],
#  'ed16421fadb3faa1acfd0a73cf2c4968d8db5c4b.jpg': ['transparent',
#   'positive/negative',
#   'greenish'],
#  '958cd309410347f61731214d1dfbeea824739ed8.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  '009f8eea52a3ac5b395e70e963ab13ad8282cdd3.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  'ca82df60ea4460d0617230b3ddbe1f3837739415.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  'fdcf54643c747e5d4b8eaa06b9e833ecb1063a28.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  'bde0d9751f76ae459b9b12e30ba792a24e47934a.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  '527d4612c6da640d628f70e83bfec1664bb07e61.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  '4ed86c791df7bf7cb1ddbc9b6a3ecd11cc3e37a6.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  'fa4e647a33a43b4251ba0b420e2345f6284f8dca.jpg': ['low-tech',
#   'solar',
#   'environmental'],
#  '18a1262a24551ddbf7abca1a540c48a18d2b1a1b.jpg': ['light-weight',
#   'casual',
#   'austrian'],
#  '3925e4580d8e1e728e7f084e82fe34528f3122c8.jpg': ['light-weight',
#   'casual',
#   'austrian'],
#  '81524629b5e40723cb741b4b85b67116ba66e901.jpg': ['online',
#   'resilient',
#   'non-standard'],
#  '44cd291cdb081d0715c10b9b0515cc22ce3fed7d.jpg': ['online',
#   'resilient',
#   'non-standard'],
#  '7bef46ac66b1b48bc756011ce9fe994ca36db2e3.jpg': ['online',
#   'resilient',
#   'non-standard'],
#  'f774e1a36aafa6538bc60d6a4ec364804cfb72a3.jpg': ['online',
#   'resilient',
#   'non-standard'],
#  '6b7844bea8485eec3107341970355291297eac65.jpg': ['online',
#   'resilient',
#   'non-standard'],
#  'd928c6d4f885ab570044ae18d5057d0ae47bdb41.jpg': ['online',
#   'resilient',
#   'non-standard'],
#  'a6b97295855c4a88af8783343a5ccbcd04ef2a15.jpg': ['chubby', 'plump', 'stout'],
#  '146f49428b0332b15026a22dda19d4f02250fb0a.jpg': ['chubby', 'plump', 'stout'],
#  '70b37d6172ef004b62605e05f10bc68fd686fcb6.jpg': ['chubby', 'plump', 'stout'],
#  'a9aad99a461950597315ee64df30988b4a2949ea.jpg': ['collectible',
#   'half',
#   'alternative'],
#  '66bc86080569209817d9efb1b91f62eba846f205.jpg': ['chubby', 'plump', 'stout'],
#  'ca5a50b9468a07393e32781e1645044a539e005f.jpg': ['chubby', 'plump', 'stout'],
#  '10533bfc7fe626911651b1c7aafdc01434ea6692.jpg': ['stripped-down',
#   'courtesy',
#   'breakout'],
#  '80f8d32c41ebddbf64c500d4e22ffb311c06c0da.jpg': ['stripped-down',
#   'courtesy',
#   'breakout'],
#  '56e81a99cb771ecaa0c2029b1cf7b9a77a87f493.jpg': ['stripped-down',
#   'courtesy',
#   'breakout'],
#  'c8d9a478840f04c36bf7ade550441844242bf505.jpg': ['stripped-down',
#   'courtesy',
#   'breakout'],
#  '36a1cba00faa608a06317b52ddaa5cf9d0343560.jpg': ['stripped-down',
#   'courtesy',
#   'breakout'],
#  '0f50a825fbe25a2240fb8117b57220c8448f2219.jpg': ['social',
#   'two-week',
#   'break-out'],
#  '7a20e8dc68d17176700b9a6c960d7db60e70b1c6.jpg': ['social',
#   'two-week',
#   'break-out'],
#  'ac4f10b6d2fdcf74b88b6c1b3e97ad2ef8f212c3.jpg': ['social',
#   'two-week',
#   'break-out'],
#  '3c998908cf48a8001515833e940e356b740e3221.jpg': ['social',
#   'two-week',
#   'break-out'],
#  'ad5e35cb8befbe3ec0773f9de2d4172a19414e41.jpg': ['social',
#   'two-week',
#   'break-out'],
#  '14366091be8a9c32f4e155ef3418e0a7fe97dd64.jpg': ['social',
#   'two-week',
#   'break-out'],
#  '2962424710df32340e29065acb0e203249c9c503.jpg': ['social',
#   'two-week',
#   'break-out'],
#  'fbef76fd34c5a83c3a8b9e65e13de3ac67dd2b71.jpg': ['l01', 'l03', 'low-rise'],
#  'e8df41c434eea26a97d8f96096c5fecac2a10207.jpg': ['l01', 'l03', 'low-rise'],
#  'c207410c8dbabf8567bd7030ec39f1079bfa4fb3.jpg': ['l01', 'l03', 'low-rise'],
#  'ca32ad3954ef3fd1c98d09f4f41bd19dc0daa57c.jpg': ['fold-out',
#   'public',
#   'flat'],
#  'd7136fa660fce635b6589c663ae193d92f8304f4.jpg': ['fold-out',
#   'public',
#   'flat'],
#  'aa2625ed83f52358ed5c8230da7296b138dcd567.jpg': ['fold-out',
#   'public',
#   'flat'],
#  'dfc9cfffa7c36e4efe94a0425bab6619bae1df77.jpg': ['fold-out',
#   'public',
#   'flat'],
#  'e192cfd1bfda287d90586a0350593950f25ee9dd.jpg': ['fold-out',
#   'public',
#   'flat'],
#  'dc38423e871fed2e39cc892ab1341fd4dfac6a8f.jpg': ['social-distancing',
#   'covid-19',
#   'global'],
#  'fbd23675cfae4ad43822a1ea00d723949d06fa32.jpg': ['social-distancing',
#   'covid-19',
#   'global'],
#  '5c0286d1e92476e7a9a07c9f60588579b32a4b4a.jpg': ['social-distancing',
#   'covid-19',
#   'global'],
#  '6b1b9d8636935b2b01ed85cdcd7ed824fd13bc42.jpg': ['social-distancing',
#   'covid-19',
#   'global'],
#  '970f98aea697d1407af517bf44892263e2c54d02.jpg': ['social-distancing',
#   'covid-19',
#   'global'],
#  '9a72107c485928afb2460d6441a37c00f5535267.jpg': ['eco-package',
#   'brief',
#   'vertical'],
#  'c55d93681f1a3edeb94dbdc634b900c714ac49e2.jpg': ['eco-package',
#   'brief',
#   'vertical'],
#  'c67786eaf05a67dd89ca846f9111e8d389fb1cff.jpg': ['eco-package',
#   'brief',
#   'vertical'],
#  '843277b72d3b43ac365d96abb72812b212b2727f.jpg': ['eco-package',
#   'brief',
#   'vertical'],
#  'bd06f0ec4834c08218847f4e52d9adbbeec48eda.jpg': ['concrete',
#   'brutalist',
#   'clunky'],
#  'd0559d34c1e62c4754f2dd998d72f480247f40cb.jpg': ['concrete',
#   'brutalist',
#   'clunky'],
#  '32a37e26c21e8d6563f648b028e0844d84bb37ac.jpg': ['concrete',
#   'brutalist',
#   'clunky'],
#  '6715be1a15599ad92858b03a5656b59e4679b349.jpg': ['concrete',
#   'brutalist',
#   'clunky'],
#  '3492082695e26ccc317914177b429f24a9f6fc80.jpg': ['unorthodox',
#   'bangkok-based',
#   'depressed'],
#  '0d263aaafe8e541164893391bce84dfdf51fa654.jpg': ['unorthodox',
#   'bangkok-based',
#   'depressed'],
#  '1009ff4fabfa5173857e1bf862b9b92c059ec073.jpg': ['unorthodox',
#   'bangkok-based',
#   'depressed'],
#  '719cfe8d3df7266fb7608b320493bf7e7981fe57.jpg': ['unorthodox',
#   'bangkok-based',
#   'depressed'],
#  '6cf38c260d1fa50ad80cd51309acc63b84720547.jpg': ['unorthodox',
#   'bangkok-based',
#   'depressed'],
#  'd03a708b73e86e288234aa18269799aeefa69434.jpg': ['refractive',
#   'reflective',
#   'satisfied'],
#  'dbeb301b6a2a3cd1ef496dccb6c5eb988b5c0ce7.jpg': ['refractive',
#   'reflective',
#   'satisfied'],
#  '67e89a4be41f10c904fd6427204be17047952531.jpg': ['refractive',
#   'reflective',
#   'satisfied'],
#  '6b83daf242cc8a27e7640b3d6cb3bb416663da56.jpg': ['refractive',
#   'reflective',
#   'satisfied'],
#  'a9d031db7e11adbba083725885e8be19db0b3970.jpg': ['refractive',
#   'reflective',
#   'satisfied'],
#  '71ec95e15d323b8c487ed192c634b102ff3dcdf0.jpg': ['japanese',
#   'evolved',
#   'renewed'],
#  'f4f40c5ce129cb1e072ce1a943d8542ccc8151aa.jpg': ['japanese',
#   'evolved',
#   'renewed'],
#  '77196103275a19d5c73f0a52550a66912f7240b8.jpg': ['japanese',
#   'evolved',
#   'renewed'],
#  '2a2093ab7967abde698b72af061d60343f9da241.jpg': ['japanese',
#   'evolved',
#   'renewed'],
#  '7d7bb08b401f418ed9c2244444ca547afc6783e7.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  '6252095df0b6ba491f88673f3447b29fbc31563e.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  '92e1afd29b061c070f0fc8c254846ff043bde0eb.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  '55bf7215f4eff08d8e977532936af5700573b8e0.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  '4ac522eb9dd9d02ed6e0f8d21357517e08e8c820.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  '0af6b26e8d826e1d3ac7f581d7e44673bce7ae8a.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  'a720ea315750d43c36401405933aa960ce7f305b.jpg': ['sparkly',
#   'glassy',
#   'molten'],
#  'a8863d634374545608fae9ab446c9d38fbec263c.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '7ab530a5d2242db0a970a4f953ae1e65953f06a2.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '1e921e338f2d471562b012d5319f42de7beab6f1.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '94a918e94295513bbcc9b8fd4c36c4a92df91524.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '95ca0cae48233597327c126ffa2227a65777fb48.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  'ce199ee1de21f0d1b204231129a90f743dbcb816.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '9a2014bde3f2b67fbdc2098acf44468c11657d69.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  'a4eacaf65f2390c4f711b10350ff4d588b83dd44.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '816488853ff5f5518548a303063a3601622df83c.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  'aba8f819cfd9d81a5f45c711841186f922af275c.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '1ef0d34234a505e27c2ab73ce92c9c800a9e9159.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '50d59b7f8e276a78fbe74ce963cca87caa041b9a.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  'ff1dbf79297c660c1ed649cdff7775c274177665.jpg': ['offsite',
#   'ambient',
#   'unseen'],
#  '66f07aa094e2a9684f33503b53f3d1a596a9e70d.jpg': ['unseen',
#   'offsite',
#   'fabricated'],
#  'e17662baa4e7ca7c345e7db33ca73ef1f6291fc4.jpg': ['unseen',
#   'offsite',
#   'fabricated'],
#  '3c100b9a2fb99b8b9cbceb65ec20a51e23180847.jpg': ['unseen',
#   'offsite',
#   'fabricated'],
#  '57dbcf049c9539b5372a3fa690b32d1dd9dfd730.jpg': ['unseen',
#   'offsite',
#   'fabricated'],
#  '14d3eb43398641ecaf8fb600d19c7d6187e4b8b7.jpg': ['unseen',
#   'offsite',
#   'fabricated'],
#  '0cd50704101e75d5254e5eae107122f068763561.jpg': ['unseen',
#   'offsite',
#   'fabricated'],
#  '5686a5567fc665576875def8660367066532a5d3.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  'd1102ecc03ced1b4840f81d7c58d666b6169ca7c.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '2df4e4ea8dc08b355ad345586c4d7a818873379c.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '66a89e8a5dd6c71c607c6aacd77d84d2080af5a5.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '11423e48bd6e6de3b85c453261e6cdc3248ff686.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  'e9bc3fa0f0cf2cf8a98fe116c8f9f3c2bdf2588f.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '7e3cd2f4a250573f1bc731883b0b71a1c082755b.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  'c7349e0ce6c8e962db296eb41e0ec7b878c4157d.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '9269c4ec28c3e2223fd286d130435388ca1e41a9.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '723c676f669b1727301bc4c9744347796304df11.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '67912b9f270ed8f36ecd86137ac4016d98742e01.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  'b2c5b6badf70631f9a12c3aa94c4d1f2d6ddb99f.jpg': ['offsite',
#   'unseen',
#   'york-based'],
#  '305ba0ada4d55a91ea362fbd859f7c05378859ab.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  '1fef8210c29e1fa4c3d2fc59a2bf15678fe0e106.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  '538bcc66abe3aa9210767cbd4fa1226efd9c9cc2.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  'e402bd151a27615b45dfc6dfb7d53aa64c777a3c.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  'fef046a6891769de7c4d55fcb8dd65de96f2e68a.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  'd4cea8c4fc7d37c53fc7b0458b36440451bd9ec7.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  '7034132bd709fc92e7895521e828f685aad6baad.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  '75bfd8f678d500e8e4af51e9452c160709ce241a.jpg': ['unseen',
#   'offsite',
#   'fluorescent'],
#  '1fa88b4f6a5a4c22ca57cedcd2e78db64b9cb533.jpg': ['unseen',
#   'offsite',
#   'virtual'],
#  'cfd23dec545659205896f4c1b07b655c162ee5e9.jpg': ['unseen',
#   'offsite',
#   'virtual'],
#  'b06214acb0150a2ee1879e6b60d9bcfa1f70758d.jpg': ['unseen',
#   'offsite',
#   'virtual'],
#  '741c610bf9c0622774ce2a70d5e2cebc8aa631e1.jpg': ['unseen',
#   'offsite',
#   'virtual'],
#  '17a79c5d97256200bcaeb173f92b6ba6330d092f.jpg': ['unseen',
#   'offsite',
#   'virtual'],
#  '62e9225e5832fb176f293bfae47bb3c9eb1f0893.jpg': ['unseen',
#   'offsite',
#   'virtual'],
#  'a0aa1c0cc399076436b9e8d14e1e04d6c07d9d59.jpg': ['unseen',
#   'offsite',
#   'common'],
#  'dc26a17810a8e3b665f4e4b22c6243acb21ea883.jpg': ['unseen',
#   'offsite',
#   'common'],
#  '6d04670e291e1e9ab16e431a339bf06911c3cc68.jpg': ['unseen',
#   'offsite',
#   'common'],
#  'ab1ad55cc1c8da16799df66356ab41c1a552d256.jpg': ['unseen',
#   'offsite',
#   'common'],
#  'f55bc9ef6e270e71972e55ce67607a231a65d5f7.jpg': ['unseen',
#   'offsite',
#   'common'],
#  'e8ab899d136c2105547acbf24eaafcd0029db7d9.jpg': ['concrete',
#   'arched',
#   'moisture-resistant'],
#  '4550a9e350336c6769fd526f6eca7f6ffecdd1b9.jpg': ['concrete',
#   'arched',
#   'moisture-resistant'],
#  '48fdcaf0aa67e48f4e14f3077cff87f964ec7e70.jpg': ['concrete',
#   'arched',
#   'moisture-resistant'],
#  'f6c184c42a3ce394900f34a59da9eb8b3d63eeba.jpg': ['concrete',
#   'arched',
#   'moisture-resistant'],
#  '11e640c565ab3b40ff998178ae1ccb4528b328f8.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  '5d64ab3ff1d39c310eac226a72307690a46bdcc0.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  '4fc2079475aa3f22c06e5b75e265a41ce4cbcfe4.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  '094f17c334d6d46607697ed61ac37dc6910c9208.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  'bdbfbae0b0987c6773008218d243d27b5ed051e8.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  'd4f44f208addf94db9ff49ae9e083dcca2022615.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  '49b1740f1625ed01bb285092eef24410cc19f873.jpg': ['feline',
#   'detachable',
#   'non-bpa'],
#  '7f41085425fca7dd5d719d9146f00605e48627a1.jpg': ['storyarchitectural',
#   'hands-free',
#   'open-source'],
#  'b14067b377a8f9eebec5aa9f83f095a9bf1fa5d6.jpg': ['storyarchitectural',
#   'hands-free',
#   'open-source'],
#  '7f456bf2da3c0a5c618b61e8ff49c1f3504c095b.jpg': ['storyarchitectural',
#   'hands-free',
#   'open-source'],
#  '5cace7ca45067929b2f73b131f43f8d9e133414e.jpg': ['storyarchitectural',
#   'hands-free',
#   'open-source'],
#  'b49ddc385546f38068542915d08f2e94ab083854.jpg': ['storyarchitectural',
#   'hands-free',
#   'open-source'],
#  '56c241cd5ae8ac231ff4460e78549557658826d5.jpg': ['storyarchitectural',
#   'hands-free',
#   'open-source'],
#  '795fe38216d717cfbf59961dbe176b2da3da6048.jpg': ['medical',
#   'sanctuary-like',
#   'elasto-mechanical'],
#  '0c7ebc1681559446fa1100e3f3bab2691e61ffe6.jpg': ['medical',
#   'sanctuary-like',
#   'elasto-mechanical'],
#  '5d4b2181540140aed60957352a980ea1cd2c3e23.jpg': ['medical',
#   'sanctuary-like',
#   'elasto-mechanical'],
#  '64cafe64def57295d74e10dd76b2572e0520aa85.jpg': ['medical',
#   'sanctuary-like',
#   'elasto-mechanical'],
#  '3565d3739b694a8e09a5f2ac82bb62dd8ae57adf.jpg': ['medical',
#   'sanctuary-like',
#   'elasto-mechanical'],
#  '5210a48cc98d50afc1aca417d3acc6fea5bd07d9.jpg': ['medical',
#   'sanctuary-like',
#   'elasto-mechanical'],
#  '362e15b3d90144248bdd367682f9ed4023287f8a.jpg': ['ukrainian',
#   'ceramic',
#   'female'],
#  '3a7e87153dd3c8dbea22a8e4ba8e279a0634a766.jpg': ['ukrainian',
#   'ceramic',
#   'female'],
#  '467d678cc86367e278b16553f2738a5c030b075e.jpg': ['ukrainian',
#   'ceramic',
#   'female'],
#  '57372c12063f7007b5f3a982317dc18fae9fc2a3.jpg': ['ukrainian',
#   'ceramic',
#   'female'],
#  '4a7b24e2bf7f71cb8161483c247cfb2219b80253.jpg': ['social',
#   'insulated',
#   'reclusive'],
#  'd29940be4d0759a7453d3405dfbdb66359d3de13.jpg': ['social',
#   'insulated',
#   'reclusive'],
#  '7fd8a4c9c9eab6f36404148707264d38c0388697.jpg': ['social',
#   'insulated',
#   'reclusive'],
#  'e249817fa6a75cc93687afffea0689c2befde5e6.jpg': ['double-width',
#   'five-centimetre',
#   'standard'],
#  '33d0831b46f69b794c6940f05337dbf2c220b29f.jpg': ['double-width',
#   'five-centimetre',
#   'standard'],
#  '5c1ab82fa344ed392e7ef7fc04e45783ed44ce76.jpg': ['double-width',
#   'five-centimetre',
#   'standard'],
#  'be7277114d19580e5fa354ae52e95435fa32cd20.jpg': ['double-width',
#   'five-centimetre',
#   'standard'],
#  '6173959517908b6693ef13be84481baa621371ab.jpg': ['double-width',
#   'five-centimetre',
#   'standard'],
#  'fc135d9dadadc42e8c96258822c3cacfa264efe3.jpg': ['double-width',
#   'five-centimetre',
#   'standard'],
#  'fd1891c028c38261aa2c29e11603e204af9d079b.jpg': ['boro-embroidered',
#   'cane-like',
#   'rust-coloured'],
#  'dbbfb6156a0888bcf59b4826a0e0ea27641c69d5.jpg': ['boro-embroidered',
#   'cane-like',
#   'rust-coloured'],
#  '7c7dde984a0a3f49439935a6ae5e689791c5d59d.jpg': ['boro-embroidered',
#   'cane-like',
#   'rust-coloured'],
#  'af19a8cd2213e93cdcc0bd118b9640aee34e8002.jpg': ['boro-embroidered',
#   'cane-like',
#   'rust-coloured'],
#  '2ac7e29b301e775e95cf4d88ccb09bdeff17c18d.jpg': ['boro-embroidered',
#   'cane-like',
#   'rust-coloured'],
#  '4d1ab4470a331d75f7a4cde85e9ee3591fec2ac0.jpg': ['boro-embroidered',
#   'cane-like',
#   'rust-coloured'],
#  '587b7ca64a9e4ea6e2098f566bc6b5abc56c7967.jpg': ['eco-package',
#   'innovative',
#   'vertical'],
#  'c009a58c785bb75687bfe3308dd4891cace89fe8.jpg': ['eco-package',
#   'innovative',
#   'vertical'],
#  'd0821d5a787d8737263c26c5c330d55a1fb0b6d7.jpg': ['eco-package',
#   'innovative',
#   'vertical'],
#  'd26d9e60fd3f54665c9c9acef5e035cf301f2f71.jpg': ['eco-package',
#   'innovative',
#   'vertical'],
#  'da00beff0e220cd931a0a3b7b2b17d8caa574ed1.jpg': ['eco-package',
#   'innovative',
#   'vertical'],
#  '7edfb17f8c730bea466c1483d911813db40a0803.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  'b45d549f774ffe86e804fa2d1f10af4e01623b70.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  '63fd84329ba3bb4a9df3b683fba20b70dadd04f8.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  '17a51a4f30b4d157c1e8e01a7ddf6aadb5076a39.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  '8abf834b599c1d956a55fa848881419a80da3a1b.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  '9b311e63a655b0b61c2052f931d3404d32c59587.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  'b4217684dbeb40904de58542c1362021df4b6fbc.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  'a1d8c5c7a39c82c151bebf0a1313a09b9f4a8c2c.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  '4cde6e2f7bd1abd4d552f277854ffb225a9a6b78.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  '2dac0d18f8322551d44f60349966af1bbbb2653d.jpg': ['muutothis',
#   'usb-c',
#   'home-office'],
#  'ff72442244e2f7be6fb8180cf20ef75d499ecced.jpg': ['remote-controlled',
#   'cramped',
#   'versatile'],
#  '223250a4e4db756a8e2df0f3d778f343ed7b0754.jpg': ['remote-controlled',
#   'cramped',
#   'versatile'],
#  '10e785c2e8c10d839b9c4b91a8e981599dcc73a3.jpg': ['remote-controlled',
#   'cramped',
#   'versatile'],
#  '12a63c0dfdf7bf6626838d75d24dadc3b747e6ab.jpg': ['remote-controlled',
#   'cramped',
#   'versatile'],
#  '3043ad522d351d8c04020dca3430c67273897e2d.jpg': ['remote-controlled',
#   'cramped',
#   'versatile'],
#  'a9ca74338e8097c05efaa6483cdfb789f13a9c6b.jpg': ['straight-edged',
#   'prism-shaped',
#   'chunky'],
#  '9f1285a573cd3b11047aaeecf86a84fbadf0d2b4.jpg': ['straight-edged',
#   'prism-shaped',
#   'chunky'],
#  'ada23705df4c5a6cfa4fbc666928d94acd3a1794.jpg': ['straight-edged',
#   'prism-shaped',
#   'chunky'],
#  'efb5778927713b81fa82796b47a3bb0451881319.jpg': ['straight-edged',
#   'prism-shaped',
#   'chunky'],
#  'f3d36b2e6e0604ecf11e7828c4ed852da06ff0b3.jpg': ['straight-edged',
#   'prism-shaped',
#   'chunky'],
#  '7fa1867506119e11309edb7a4f8bfb1888263808.jpg': ['undulating',
#   'solid',
#   'fleeting'],
#  '48dd85f7fad4dea540cd18f0361a19968a4a8643.jpg': ['undulating',
#   'solid',
#   'fleeting'],
#  'b4a2b8161341a4c5f750b7188160509f703c32ee.jpg': ['undulating',
#   'solid',
#   'fleeting'],
#  '9866edf08b0574339f687e40dd6ba8d290d36aa0.jpg': ['undulating',
#   'solid',
#   'fleeting'],
#  '2fc80bb41fccdcf22947c837ab5f91937074146c.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '5e978df1d5d89e8945a01816eb7074646cd69127.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '4088c1bf4c8dfda96182fcd0936ae002f4b95739.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '8652b5e524e87a8ec974dab3320530ae68b6eb42.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  'a4624b1e77250a3778f09c3fbedc6c6b5b4b40ab.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '1fe40d44125837b3c9ff7205f1bdc0cc9bc496f4.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '9a124f951274729bf2d14e180375122b513f6b91.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '10651338700033c69bd90c7e177c50aab96f707d.jpg': ['devious',
#   'sumptuous',
#   'rigid'],
#  '9de7e988c9e52aff95d4bf54af883691c0c7bbaf.jpg': ['turned',
#   'rococo',
#   'danish'],
#  'c4087d0ad5fb4d1c18dc95c1f0c7e0ad21c66673.jpg': ['turned',
#   'rococo',
#   'danish'],
#  '53b8f54fe2343914cbe9452a5a60a9a3ba9eb8bc.jpg': ['turned',
#   'rococo',
#   'danish'],
#  'a85b5350abf38a7732338152adb80409d24c79e0.jpg': ['turned',
#   'rococo',
#   'danish'],
#  '9e28d82795e9206ecdef11e6ca27bb410384c31e.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  '85200aae5314c3c4f5d76a13e2bf723596960e9d.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  'f89ed5a0dfb81ce5722178d2e3fe185bf8723855.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  'f8d5890d75eaddad0c8467837f263d664b8c8078.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  '46f9ea610744e1b5cb436896e70e89b22f7ad7c2.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  'b2a7a17755cb0d87f2654aa399a0d9c6cd9e45ef.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  '3f93d829b48aa1c8d6addb3ae7ca86dc743dc0ba.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
#  '3956927b765d445015a0f9ddd7301f66546871d8.jpg': ['finnish',
#   'nordic',
#   'wiggly'],
# ...
#   'synesthetic'],
#  '3cde2341235b7180b33b5e076dbbf71aa0a88da8.jpg': ['musical',
#   'persian',
#   'synesthetic'],
#  '51b1d70ebb711ca7e94bca67824783c4ed29eefc.jpg': ['musical',
#   'persian',
#   'synesthetic'],
#  '843cb318b870f46b9450d6e55fda9294235839c4.jpg': ['musical',
#   'persian',
#   'synesthetic'],
#  '644a8d142baa0616745e3908e6801bffd0be5e6b.jpg': ['musical',
#   'persian',
#   'synesthetic'],
#  '35f8eb92a2bbf6e16f2e9a58f626b8032a4a7ca4.jpg': ['musical',
#   'persian',
#   'synesthetic'],
#  '0b1f4ebed375bc195bcf5f5fda75ef16ac11a592.jpg': ['recycled',
#   'plastic-packaging',
#   'key'],
#  '42845d9254690cc3a64e8fee6d808a71fe13fbbc.jpg': ['recycled',
#   'plastic-packaging',
#   'key'],
#  'f43b45d559f12ebbdc10f2f3e47336c4981d6ab4.jpg': ['recycled',
#   'plastic-packaging',
#   'key'],
#  '4e63905fe8c638e27bc0913ae123fa52cde71bf8.jpg': ['recycled',
#   'plastic-packaging',
#   'key'],
#  'e77fea6747de581cf07ab8ecff0784ca75a088a1.jpg': ['dystopian',
#   'beige',
#   'sand-covered'],
#  '60db2b741fd31d1bea6fd5def49b259148cc47a2.jpg': ['dystopian',
#   'beige',
#   'sand-covered'],
#  '27feb6c3e156404f834f4a682787243e689f2c0e.jpg': ['dystopian',
#   'beige',
#   'sand-covered'],
#  'd4c49af3e35420a1cd62921cb7166e325cb0223a.jpg': ['african',
#   'south',
#   'futuristic'],
#  '76eb3b74ebe454bd4f64e9ecfb636099b694db3f.jpg': ['african',
#   'south',
#   'futuristic'],
#  '3fdddab2535065ed34c3bcb7eb860cc14ae12a44.jpg': ['african',
#   'south',
#   'futuristic'],
#  'e4fc96fbd7eeca66ad54b177850345fafa29e6b4.jpg': ['african',
#   'south',
#   'futuristic'],
#  'e85fac2d86b9526719c7edd75562724819d92746.jpg': ['african',
#   'south',
#   'futuristic'],
#  '41353a3cd1dc6b71840ab26ff43199967c0a63d1.jpg': ['african',
#   'south',
#   'futuristic'],
#  '2cce764d28a239f2cad6bb1fa3da52def4785e3c.jpg': ['convivial',
#   'divergent',
#   'club-style'],
#  '70dc8632ab7cf82e578f37682542ef7fe1d095f4.jpg': ['convivial',
#   'divergent',
#   'club-style'],
#  '28d62f7e92cae3d0cb41988d42c5a3edb15c2e40.jpg': ['convivial',
#   'divergent',
#   'club-style'],
#  'ceaf0b93ff38884dd6d04cf120658e2675e8d1ae.jpg': ['convivial',
#   'divergent',
#   'club-style'],
#  'b974b722c0167961f71280861ddb30b304c18fa9.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  '65ff7137313c6c88f80f31a3a2fb3e18e7838d2f.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  'df9ef8aea782676628b2cf78a40c8c7babcfcac9.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  'dd41c12a1205bff8dc4f25bc477a8a008ea8bfe8.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  '2417eb82619c91a0c7ede8a666d08484a86b5dbe.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  '4362b67520e2944c05fd258aa9d531612c81bdc9.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  'acdef007cef8ec3854950ddb0b496fc2f3914be7.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  '7acf6a67c165e25af73abbe944d49b608252b9f0.jpg': ['first-come-first-serve',
#   'glad',
#   'long-awaited'],
#  'b8bd9cf07f1d9267a1dee7bec182c465c674aab5.jpg': ['woven-cane',
#   'doodle-like',
#   'one-armed'],
#  '437ce6c03b619a4d02e87a92ac988716a2062e38.jpg': ['woven-cane',
#   'doodle-like',
#   'one-armed'],
#  '76f931a77e3f95e4452a77edcc486f5e0364b77e.jpg': ['woven-cane',
#   'doodle-like',
#   'one-armed'],
#  '241f501975b64ee85ae54ccfb4aa8c8c348edee6.jpg': ['woven-cane',
#   'doodle-like',
#   'one-armed'],
#  'a1904d141bcaf14e56954e24ed1092a78d948eec.jpg': ['undergraduate',
#   'fluorescent',
#   'multi-sensory'],
#  '927bd699589a0a4c215df10780d3a4c64257061e.jpg': ['undergraduate',
#   'fluorescent',
#   'multi-sensory'],
#  '3ab6e913aeacc707fe27964088bee12c48333c06.jpg': ['undergraduate',
#   'fluorescent',
#   'multi-sensory'],
#  '99921b53fa404135dbc22bc0ee9758b19754e9be.jpg': ['undergraduate',
#   'fluorescent',
#   'multi-sensory'],
#  'a194e175273a24e50145721fc3b09850f1d5609c.jpg': ['constituent',
#   'absent',
#   'original'],
#  'a2a482d42a21e2e3bff688b96759b647de175a06.jpg': ['constituent',
#   'absent',
#   'original'],
#  '56ba4f9e1d1632bb6588fa48d89b504e5bdf324e.jpg': ['constituent',
#   'absent',
#   'original'],
#  '3a21a82bee5bdf60edcc125b3842592a4cc8aa54.jpg': ['constituent',
#   'absent',
#   'original'],
#  'c33ee25aa1637bb083ea8001b215a2bb75f27e2a.jpg': ['constituent',
#   'absent',
#   'original'],
#  'c2c65817a629ee5f8cd71ff4fc746a52686fb77e.jpg': ['constituent',
#   'absent',
#   'original'],
#  'd7662e819b1340884ab3edbbd24ec47d579c1be5.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  '2076e51e184c91803c529a71dfc375e156bf4c77.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  'fcbc3e12c637b000389964ee3fe44e58eb353f06.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  'ba9bd00d540cdce8e973b565ee156e3ceeffc338.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  '1aacb7eadcada50b8de58507273e5b3069f11255.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  'bbe5cb5394e8ffe80a064b25ea0d2f97eb28bc74.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  '91efbf13d2a17be5f5076c30051744f87d7ee93c.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  'ea98c3ab6550a0063f354923aeda26c658df3d86.jpg': ['harvestable',
#   'converted',
#   'tree-based'],
#  'c11797f3549e2b57510fd0783f9d3d23de3ad259.jpg': ['professional',
#   'room-partition',
#   'double-height'],
#  'ba47df8d82494f30296f0ee4ea2d1e1f7dbb64ea.jpg': ['professional',
#   'room-partition',
#   'double-height'],
#  '86753d1bf49031c35777dd7d99d0f306768a392e.jpg': ['professional',
#   'room-partition',
#   'double-height'],
#  '5eb8ab874721c4da4f01b426ce7a6f1355719ab3.jpg': ['professional',
#   'room-partition',
#   'double-height'],
#  'd20b5fbae95283ad0c905385dea2bed0bcc283fe.jpg': ['professional',
#   'room-partition',
#   'double-height'],
#  'ad0f823781024633a772f290171af218ae9457ac.jpg': ['professional',
#   'room-partition',
#   'double-height'],
#  'b9a783f0b36bed6419765f855466b367b02d6c09.jpg': ['mexican',
#   'blush-coloured',
#   'net-like'],
#  '570bd930a6822ce36f7227730c096a2f4a843d77.jpg': ['mexican',
#   'blush-coloured',
#   'net-like'],
#  'a25884af4bab3288a94349f610c6f97e711cd769.jpg': ['mexican',
#   'blush-coloured',
#   'net-like'],
#  '5b1dac16bae26aa2ea65de6b27b52776a5a2e1a5.jpg': ['mexican',
#   'blush-coloured',
#   'net-like'],
#  'd06e38b237b928dae8befa2c405bf55ada263e5b.jpg': ['mexican',
#   'blush-coloured',
#   'net-like'],
#  '555f04b38dad733b4b5d606008520f91655b4f09.jpg': ['sustainable',
#   'cooperative',
#   'fsc-certified'],
#  'a763c61ed8a75f9b4bac952363c098ea0f28189c.jpg': ['sustainable',
#   'cooperative',
#   'fsc-certified'],
#  '160d61656c14847b9b64ab31976107d0eabed364.jpg': ['sustainable',
#   'cooperative',
#   'fsc-certified'],
#  '0dc089eb8f7e5fed01a11a40987c04e8e73aaac1.jpg': ['sustainable',
#   'cooperative',
#   'fsc-certified'],
#  '9a3bd039f6892d986b176d7da43ae258ab7fccc2.jpg': ['sustainable',
#   'cooperative',
#   'fsc-certified'],
#  'ea723c5ed004e3a973abb153a9d576c78c0b724d.jpg': ['sustainable',
#   'cooperative',
#   'fsc-certified'],
#  '670790f12d036f29921652d9122dda604ff3f2af.jpg': ['plastic',
#   'impatient',
#   'worthy'],
#  '5bf489904c532c9a6345b50eff989edbec214a46.jpg': ['plastic',
#   'impatient',
#   'worthy'],
#  'f84cf601fbaa53674f7ab9f43e4bfe53ccfa652b.jpg': ['plastic',
#   'impatient',
#   'worthy'],
#  'ed987c3744377171b06066905330593798546c55.jpg': ['plastic',
#   'impatient',
#   'worthy'],
#  '98651c332e4b16993f4af264e0dc1b1150d5a5d4.jpg': ['plastic',
#   'impatient',
#   'worthy'],
#  '88008d506c8ac7e0536d79ff99d545f41dc47267.jpg': ['plastic',
#   'impatient',
#   'worthy'],
#  '633f25ae45b446c2d1c3bd54df7388c0e554cae4.jpg': ['grungy',
#   'gothic-inspired',
#   'phone-charging'],
#  '9f6edbaa459cb2551ed9d21de58bc110cf7d8b23.jpg': ['grungy',
#   'gothic-inspired',
#   'phone-charging'],
#  'd977ba88c642620b0d4d0b0a1dbf01d6029a11a3.jpg': ['grungy',
#   'gothic-inspired',
#   'phone-charging'],
#  '07d5199705191c4ad4605877b28fec27a11e80fc.jpg': ['grungy',
#   'gothic-inspired',
#   'phone-charging'],
#  '0d46a3ed6b699d3eaf22b932b7e80ec6f892cc29.jpg': ['grungy',
#   'gothic-inspired',
#   'phone-charging'],
#  'ab89f91442c0001342b3a21dae6a10fb6c29a8ee.jpg': ['wave-like',
#   'cartoon-style',
#   'pedestrianised'],
#  '30458544dc7639994e23f1bd5db18a1cb27416a4.jpg': ['wave-like',
#   'cartoon-style',
#   'pedestrianised'],
#  '8277cca162f93c8edeb0baacf2e2aec3b7e8c036.jpg': ['wave-like',
#   'cartoon-style',
#   'pedestrianised'],
#  'd4a29321dc84e5b4c08c0f20e6ff9e3e103c9349.jpg': ['wave-like',
#   'cartoon-style',
#   'pedestrianised'],
#  '25e8a7e122e569bcea049b4de84010fd5c568f6d.jpg': ['big',
#   'surprising',
#   'oppressive'],
#  'eb5bcf7f0f1030c21b42c2fd1372798d97f07d99.jpg': ['big',
#   'surprising',
#   'oppressive'],
#  '9454dfc41290927389afa8d735199ed24c287146.jpg': ['big',
#   'surprising',
#   'oppressive'],
#  '20d8a63701642b7f7bcbf57179d4b235a2671b52.jpg': ['big',
#   'surprising',
#   'oppressive'],
#  '56d9ee49a203d12055382da62666553b4cab4e1a.jpg': ['big',
#   'surprising',
#   'oppressive'],
#  'bde1d221a2496b2cb28b55719dd1f7090b578954.jpg': ['big',
#   'surprising',
#   'oppressive'],
#  '278e3f51ff67170fd2d3883bcc68063a76d9d68e.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  'd36e62936187881e764b02d7a5914e6121079937.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  'ba19526dc3dadc174f887a74653dc2283b71fc05.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  '533596a358d930606f7afc89df70f6ee02e1410d.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  'f0c963fb0bcd2953054a34595ab886822735d49f.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  '414a2a0147c5025d9401dfea622536fda983a85e.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  'c0286b6ca6137e5d488a07bc2ff09ee912d55ab7.jpg': ['sustainable',
#   'environmental',
#   'sit-stand'],
#  '49b09402a1092ee0eed8ca2c56d86d416b275ace.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  'aba2278bc650e60e2ddf496f499abd9b1bbfd46f.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  '47b602c7718ee6b951dc553b08da24ffed5683b7.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  '2282dc0863e68f106dff7c38eee3879db48fa545.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  'dac37e7aaaa6050dd1d07ab098b12c5474c50ea8.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  '456ab0a62ca7270b3acb09336ba9dd991710fb2c.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  'bc9b5d825eaaaa2cc08fe3fb6603de8ebbff423a.jpg': ['mid-century',
#   'upstate',
#   'australian'],
#  '7c35a642ac9425928d5f0b98c35a055e25695709.jpg': ['european',
#   'sewn',
#   'peaked'],
#  'c4107322ca6db48be1107530f0504fcbe563650f.jpg': ['european',
#   'sewn',
#   'peaked'],
#  '0a2965ed1316a69ea63bdcfe10ea492a058ff038.jpg': ['european',
#   'sewn',
#   'peaked'],
#  '5c760e2964393abde3b8480da180e9c250d8cda7.jpg': ['european',
#   'sewn',
#   'peaked'],
#  'f294157f172727ef8a2ba46a9c1c838fec78c107.jpg': ['european',
#   'sewn',
#   'peaked'],
#  'e5849d76fba367396ca8e0258a6cfdd27d4b6986.jpg': ['european',
#   'sewn',
#   'peaked'],
#  '10d26d1e6d624dc17d6662b76115accbbe0c4f16.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  'e39f88115fc8569383e38b6cd1b94a92af0b7f8e.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  'c7215ed2e83b7a21bf2beb1fdf0e5df9e63dcc17.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  'd69fb7a77282cd651c642d55b230be4c55a49e43.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  '165d52a2efe13d3d99d88be4718d06aa76a42d15.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  '3c69089b1143c49c756abb67292130ab39093cb1.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  '1b1677b62850d3d44de408e44d6820931bad311d.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  '6a8d69d9f0e615668709167064e9b42483240e76.jpg': ['brick-clad',
#   'full-floor',
#   'grayish'],
#  'd7862195f81b3b235cfcfb2416110702a5f5c33b.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  '6134279b698c3e5874ec0c9631382ad9e506834b.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  '3ec7df968f7d0fcd7838326ca99a52f976205894.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  'b8591fcc2bb5f00866b345b56946ee9975b32f7a.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  'fc1cd780be0c9196acbedac26d1f130728f2eb83.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  'a10715e1ac4ecd314ea76f8ceea28bfc3715ee51.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  '60e551ee857945eea5be347da5b8bc5e2380b256.jpg': ['sustainable',
#   'recyclable',
#   'non-polluting'],
#  'bc7ef703e8136f7fcbeffd53228a3544da1ed82c.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  '4e08b8043530e7c44d645c40a6999c5a8a1b0af9.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  'dd05de242323916d92ef188c67a31497c8884b08.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  '00832292381bb259d89a1c3f262280406b0eda15.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  '02b9f1a06b62c6347cc6f840bfa48db207578a9b.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  'ef75b681e4e419bf1b6b22e2b2c9230977434ead.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  'c537a8cb84c4e72a4b0854665a059c6dacb77ce3.jpg': ['celestial',
#   'astrological',
#   'rainbow-like'],
#  '0f9939ffbc007b9e02f58e351c895b8d75d64b94.jpg': ['washer-drier',
#   'phenomenal',
#   'replaceable'],
#  '5af217238afccffdfe1e8983d3a2ad2c7df28561.jpg': ['washer-drier',
#   'phenomenal',
#   'replaceable'],
#  '2883d9adb959ada83bb4ff4cf639f0e84bdeb6af.jpg': ['washer-drier',
#   'phenomenal',
#   'replaceable'],
#  'ebd2e069a19e310e5d440a512ae9140d2d0886be.jpg': ['washer-drier',
#   'phenomenal',
#   'replaceable'],
#  '0aa96472b3f8e6f3b4d513854e2dc12664485a3b.jpg': ['washer-drier',
#   'phenomenal',
#   'replaceable'],
#  '2c412e1ed483d09151bdc8235cd6c8e5d1c6ec67.jpg': ['washer-drier',
#   'phenomenal',
#   'replaceable'],
#  'c8a0daf4979d3724c784724e7edb5ecc646d0bf5.jpg': ['sheet-like',
#   'intact',
#   'uninterrupted'],
#  '5ad6f63743cd6c596831d632db3c2ccaa41fc4b5.jpg': ['sheet-like',
#   'intact',
#   'uninterrupted'],
#  'ac346a59b7faa4a62add7bcda28649e2caa5e091.jpg': ['sheet-like',
#   'intact',
#   'uninterrupted'],
#  '74bada0dc06d6256438733a96b9189396e7bbd6d.jpg': ['sheet-like',
#   'intact',
#   'uninterrupted'],
#  'e786d4314df5dbf3ed7fd9aee7ac6408a8eb9df4.jpg': ['sheet-like',
#   'intact',
#   'uninterrupted'],
#  '43949fca646262afafc02662924dff21ea3679e9.jpg': ['sheet-like',
#   'intact',
#   'uninterrupted'],
#  'f1afe240dadbaf5c1fa01b2b6b9fd0b7d838f5f3.jpg': ['chinese',
#   'contemporary',
#   'middle-class'],
#  '07d1e6a8179922e0638b452fc4fb9ca2098d517f.jpg': ['chinese',
#   'contemporary',
#   'middle-class'],
#  '1bbaf09d0e25241593b67a57f6aff48b7bc0768f.jpg': ['chinese',
#   'contemporary',
#   'middle-class'],
#  '4105fe018693981fb0f659f0dce6723724d15c60.jpg': ['chinese',
#   'contemporary',
#   'middle-class'],
#  '58ac25edd5ddaa098a0ccc4298684115ae322b72.jpg': ['chinese',
#   'contemporary',
#   'middle-class'],
#  '4ce9fa97516b59bfbfd82050b747fe6a7fbd7e2f.jpg': ['chinese',
#   'contemporary',
#   'middle-class'],
#  '9df21db20192ca6b4d6f725d38833677811b3834.jpg': ['oval', 'good', 'proper'],
#  'd9eaafeef8c5d89047469493548f976aa5a2f64e.jpg': ['oval', 'good', 'proper'],
#  'a9dd63d592f0c77ccb107c27dc786de362588142.jpg': ['oval', 'good', 'proper'],
#  '1c33501733a21de39bdb6b90c6a13a299e99fe56.jpg': ['oval', 'good', 'proper'],
#  '2b0a9780cef1c9d2d3cd1479462a06c209b08ade.jpg': ['oval', 'good', 'proper'],
#  '3817d7508a68a0b8341de0acb1d3e3dc77369f1b.jpg': ['oval', 'good', 'proper'],
#  'e81cb85907ee9ea30aeec32c8162325c9a1f22bd.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  '4a752a9a9164807fa8a9a6b26a87d238b792e2bd.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  '3af126b1b1bc32253f6bb5e288969efb39a758cd.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  '7556d9dca6c77db3a0dafc903b4a02ed0fd22d11.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  'be859f5d182272881e823e061b3e662172b8067e.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  '806a69fae5d047420ac89487c25cd7214b0c6ff2.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  'f555f69053bcc69fffbe70de2ff2eaeceddb5ad7.jpg': ['textile',
#   'dutch',
#   'print-like'],
#  'f10115e45d06a2a9921abda658ff3282cc7cd610.jpg': ['sexist',
#   'powerful',
#   'imperative'],
#  '36fdd6da529f54ff20e932d2953b14178691650d.jpg': ['sexist',
#   'powerful',
#   'imperative'],
#  'b911990f3da768bf74d7d9d53df7f97ad6fccd62.jpg': ['sexist',
#   'powerful',
#   'imperative'],
#  'eaca6a80388c79e55429dc3687cb1d8a9f5eb7dd.jpg': ['sexist',
#   'powerful',
#   'imperative'],
#  ...}

# %%
save_json(save_file_path + 'ADARI_furniture_tfidf_top3adjs.json', topK_tf_idf)
